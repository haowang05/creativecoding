# %% [markdown]
# # Generate with NanoGPT
#
# Here we are going to take our trained model and generate new text with it.
#
# First lets do some imports:

# %%
import os
import torch
import pickle
import tiktoken

from contextlib import nullcontext

from nanoGPT.model import GPT
from nanoGPT.config import ModelConfig

# %% [markdown]
# ### Generation hyperparameters
# If you are on an M1 macbook or have an NVIDIA GPU, you may want to change the device from cpu to `mps` or `cuda` for faster training.

# %%
init_from = 'resume' # either 'resume' (from an out_dir) or a gpt2 variant (e.g. 'gpt2-xl')
ckpt_dir = 'ckpt/shakespeare-char' # ignored if init_from is not 'resume'
num_samples = 10 # number of samples to draw
max_new_tokens = 500 # number of tokens generated in each sample
temperature = 0.8 # 1.0 = no change, < 1.0 = less random, > 1.0 = more random, in predictions
top_k = 200 # retain only the top_k most likely tokens, clamp others to have 0 probability
seed = 1337
device = 'cpu' # examples: 'cpu' (standard), 'cuda' (NVIDIA GPU), 'mps' (Mac M1/M2/M3)
dtype = 'float16' 
compile = False # use PyTorch 2.0 to compile the model to be faster
ctx = nullcontext()

# %% [markdown]
# ### Start seed for text
#
# This string will be the starting point for our text.
#
# If you want something longer you can load in a text file to condition the model, by adding the prefix: ` "FILE:prompt.txt"`.

# %%
start = "Once upon a time" # Can also specify a file

# %% [markdown]
# ### Load model and generate

# %%
# model
if init_from == 'resume':
    # init from a model saved in a specific directory
    ckpt_path = os.path.join(ckpt_dir, 'ckpt.pt')
    checkpoint = torch.load(ckpt_path, map_location=device)
    checkpoint_model_args = checkpoint['model_args']
    m = ModelConfig.from_dict(checkpoint_model_args)
    model = GPT(m)
    state_dict = checkpoint['model']
    unwanted_prefix = '_orig_mod.'
    for k,v in list(state_dict.items()):
        if k.startswith(unwanted_prefix):
            state_dict[k[len(unwanted_prefix):]] = state_dict.pop(k)
    model.load_state_dict(state_dict)
elif init_from.startswith('gpt2'):
    # init from a given GPT-2 model
    model = GPT.from_pretrained(init_from, dict(dropout=0.0))

model.eval()
model.to(device)
if compile:
    model = torch.compile(model) # requires PyTorch 2.0 (optional)

# look for the meta pickle in case it is available in the dataset folder
load_meta = False
if init_from == 'resume' and 'dataset' in checkpoint: # older checkpoints might not have these...
    meta_path = os.path.join(checkpoint['dataset'], 'meta.pkl')
    load_meta = os.path.exists(meta_path)
if load_meta:
    print(f"Loading meta from {meta_path}...")
    with open(meta_path, 'rb') as f:
        meta = pickle.load(f)
    # TODO want to make this more general to arbitrary encoder/decoder schemes
    stoi, itos = meta['stoi'], meta['itos']
    encode = lambda s: [stoi[c] for c in s]
    decode = lambda l: ''.join([itos[i] for i in l])
else:
    # ok let's assume gpt-2 encodings by default
    print("No meta.pkl found, assuming GPT-2 encodings...")
    enc = tiktoken.get_encoding("gpt2")
    encode = lambda s: enc.encode(s, allowed_special={"<|endoftext|>"})
    decode = lambda l: enc.decode(l)

# encode the beginning of the prompt
if start.startswith('FILE:'):
    with open(start[5:], 'r', encoding='utf-8') as f:
        start = f.read()
start_ids = encode(start)
x = (torch.tensor(start_ids, dtype=torch.long, device=device)[None, ...])

# run generation
with torch.no_grad():
    with ctx:
        for k in range(num_samples):
            y = model.generate(x, max_new_tokens, temperature=temperature, top_k=top_k)
            print(decode(y[0].tolist()))
            print('---------------')
# Out:
# number of parameters: 10.65M
# Loading meta from ../data/class-datasets/text-datasets/shakespeare_chars/meta.pkl...
# Once upon a time brand thel hew?
#
# MOFLOUS:
# DOUS:
# Herer tim deral my ony tend.
# Havay alld by patatheis weshoutite th u be;
# Gedou d tan! cusemiserthace in wis, h ll ethes mour sut nt; belllo Ones arthind ale
# And tin chas or teabearsthin rstth tag me: gand wousind gr bengevet tis f br.
#
#
# MEOLONCK:
# Domer t ped bellin le, gher, wil'sthas r nede andd,
# Ano st nd thor buth sthe, aroten:
# Ase beangs frtove choug ath blele; o tot t te poret sthethe tho he anome hof acte toalelich, headoutonin
#
# Lit t mo this asendoo st
# Qul
# ---------------
# Once upon a time thas, sis to sovest ill toin mom orh coune ais wis
# Here lelld the blo the om-now ot-sth sealste
# Dew ma couce nth henow wnize w ce sone somanthe olll.
#  Gemin r owithsere Hang
# Gon d d, weay, is nouth I t mest! gherd nofl an.
#
#
# GLORY:
# So fe itowand he the hirer wiratove h s cor ling thenrsthe asrenghe
#
# I o wat we t by shee the cyord whiu. ld thalche thetofr y, the rodofis marodon nttor ted?
# Ro nun gu fonde te an had ath wince g sulto tisot s towoos atarther:
# atth merinthe sath ang whersis tinontat
# ---------------
# Once upon a timesten thand tof is thard
# And fram, bere mus no tand ave detwond ove prthengem rigith ang besucede nd
# Ofricer ang an toucot he foincemom cha.
#
# ISOFWARIOM:
# A atoth y foon, tof th aninthe s vionour rar lame by tosing; me oond te ho bethsouk'sthanof
# And one am that ht be therome waveailay tie helert he dshourobareerean thensth aie thed.
#
# ALAMINad s ss herave mooururrrd asan thandiso lo.
# I thit I outot Sis foouns her f fami we thakise marthe wer l fo us yor hasorter?
# Heverr wedin wacarme the iment hin
# ---------------
# Once upon a time poplaist o thery!
#
# Sing th be sis seer be Goren thin:
# Tileat t bens, angh wo ththeis, herthes leris t ll his
# An ldeig mer bld aneat mino w.
#
# PORY RK:
# Whe t he:
# Thanoue g an ckes se And theere ardrd f by g theasher gid reas
# Clofondsuth t; s oorcust he he th.
#
# ARIOLEO:
# Sof catoo ul blyo rn I tho en bsond aspamesbe.
#
# Thasp t Corert br tordome mun ait tol thesry whe.
# Thitharstod'sh wheinty sthe yotheaie s agias ar lit,
#
# Who
# CLelld, t th we me gorod athoraing toore'ss to f nd ago mas anoore nd theen
# ---------------
# Once upon a timed lod, nend peear oviel anth,
# Nong at mout ames pedingnd tongly,
# Tort fong thay hin bing le halang akeam.
#
# TENTHARD NG ED:
# Wasthero ithe thisthooueng t at soy arnde foul tous, toun ul od
# The mer le spoof wathes and th bl
# Wifor int, ore ble't be n.
#
# IORD:
# I the f ar ildindo me henthewisho sol meangy t itheden than his myo the y litheandd
# The s thal.
# FRIOVIO:
# W:
# Prre, the sI teke mofo dathat ar d hout wo ceeal is; ail, o me; you u hell me nd t dor sowou ther,
# The athift r the bicor thor the
# thit o
# ---------------
# Once upon a time; thint,
# When For thal willy lo rof them an ay.
#
# Fin TInour, qul Coullde hest t douace th fo our atatoulen se?
#
#
# CLOUS:
# Thout sthy tou to thee, ous I o itofocan
# Sel w or, yo ye are ce hene tleal akit ve, athere p co pa fde sul the heno,
# Ansiteced werd ke bend t and lon dulieagherew'd g f co withar lseng meave oV
# Bullif aresth ththen asthalf
# Theacorithous tounbru o haim a ond, trintes he hatrintheror har beatindachad
#
# at is me br pre ting tese frentor are.
# Healinkelem
#
# DUSORK:
# As ar fe muthake th
# ---------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 55
#      53 with ctx:
#      54     for k in range(num_samples):
# ---> 55         y = model.generate(x, max_new_tokens, temperature=temperature, top_k=top_k)
#      56         print(decode(y[0].tolist()))
#      57         print('---------------')
#
# File /opt/miniconda3/envs/coding3/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Documents/msc/codingt3/Assignment/week-5/nanoGPT/model.py:312, in GPT.generate(self, idx, max_new_tokens, temperature, top_k)
#     310 idx_cond = idx if idx.size(1) <= self.config.block_size else idx[:, -self.config.block_size:]
#     311 # forward the model to get the logits for the index in the sequence
# --> 312 logits, _ = self(idx_cond)
#     313 # pluck the logits at the final step and scale by desired temperature
#     314 logits = logits[:, -1, :] / temperature
#
# File /opt/miniconda3/envs/coding3/lib/python3.12/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/coding3/lib/python3.12/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Documents/msc/codingt3/Assignment/week-5/nanoGPT/model.py:177, in GPT.forward(self, idx, targets)
#     175 x = self.transformer.drop(tok_emb + pos_emb)
#     176 for block in self.transformer.h:
# --> 177     x = block(x)
#     178 x = self.transformer.ln_f(x)
#     180 if targets is not None:
#     181     # if we are given some desired targets also calculate the loss
#
# File /opt/miniconda3/envs/coding3/lib/python3.12/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/coding3/lib/python3.12/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Documents/msc/codingt3/Assignment/week-5/nanoGPT/model.py:110, in Block.forward(self, x)
#     109 def forward(self, x):
# --> 110     x = x + self.attn(self.ln_1(x))
#     111     x = x + self.mlp(self.ln_2(x))
#     112     return x
#
# File /opt/miniconda3/envs/coding3/lib/python3.12/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/coding3/lib/python3.12/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Documents/msc/codingt3/Assignment/week-5/nanoGPT/model.py:81, in CausalSelfAttention.forward(self, x)
#      78 y = y.transpose(1, 2).contiguous().view(B, T, C) # re-assemble all head outputs side by side
#      80 # output projection
# ---> 81 y = self.resid_dropout(self.c_proj(y))
#      82 return y
#
# File /opt/miniconda3/envs/coding3/lib/python3.12/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/coding3/lib/python3.12/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/coding3/lib/python3.12/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
