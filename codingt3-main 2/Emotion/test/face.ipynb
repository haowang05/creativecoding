# %% [markdown]
# ## Create Environment
#
# `conda create -n genet3 python=3.10`
#
# Activate Environment
#
# `conda activate myvoiceenv`
#
# Install Dependencies
#
# `pip install deepface`
#
# `pip install tf-keras`

# %% [markdown]
# ## Integrating Emotion Analysis Model
# https://github.com/serengil/deepface
#
# I integrated the DeepFace library to enable real-time facial emotion recognition using a webcam.
#
# The main steps included:
#
# * Activating the webcam to capture live video input.
#
# * Running real-time emotion analysis on the detected faces.
#
# * Since the detection runs continuously, I made several performance optimizations to improve efficiency and reduce lag.
#
# After these adjustments, the system was successfully tested and performed as expected.

# %%
import cv2
from deepface import DeepFace

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    try:
        result = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False)
        print("Result:", result)
        dominant_emotion = result[0]['dominant_emotion']
        cv2.putText(frame, dominant_emotion, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 
                    1, (255, 255, 255), 2, cv2.LINE_8)
    except Exception as e:
        print("Error:", e)


    cv2.imshow("Emotion Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Result: [{'emotion': {'angry': np.float32(6.285331), 'disgust': np.float32(0.31108153), 'fear': np.float32(22.201189), 'happy': np.float32(0.2449075), 'sad': np.float32(0.04368118), 'surprise': np.float32(70.88172), 'neutral': np.float32(0.032094754)}, 'dominant_emotion': 'surprise', 'region': {'x': 561, 'y': 403, 'w': 264, 'h': 264, 'left_eye': (753, 518), 'right_eye': (619, 510)}, 'face_confidence': np.float64(0.96)}]
# Result: [{'emotion': {'angry': np.float32(3.2763283), 'disgust': np.float32(0.00017697626), 'fear': np.float32(8.431003), 'happy': np.float32(0.0061915903), 'sad': np.float32(40.313564), 'surprise': np.float32(0.0013156997), 'neutral': np.float32(47.97142)}, 'dominant_emotion': 'neutral', 'region': {'x': 564, 'y': 409, 'w': 250, 'h': 250, 'left_eye': (665, 593), 'right_eye': (618, 510)}, 'face_confidence': np.float64(0.96)}]
# Result: [{'emotion': {'angry': np.float32(0.0014314295), 'disgust': np.float32(0.00012869052), 'fear': np.float32(0.9605963), 'happy': np.float32(94.46725), 'sad': np.float32(3.9321666), 'surprise': np.float32(4.2458192e-05), 'neutral': np.float32(0.63838404)}, 'dominant_emotion': 'happy', 'region': {'x': 563, 'y': 408, 'w': 256, 'h': 256, 'left_eye': (756, 517), 'right_eye': (666, 592)}, 'face_confidence': np.float64(0.94)}]
# Result: [{'emotion': {'angry': np.float32(11.718832), 'disgust': np.float32(0.28172362), 'fear': np.float32(0.20131151), 'happy': np.float32(0.00013862907), 'sad': np.float32(0.0014270352), 'surprise': np.float32(87.79649), 'neutral': np.float32(7.960289e-05)}, 'dominant_emotion': 'surprise', 'region': {'x': 553, 'y': 406, 'w': 273, 'h': 273, 'left_eye': (752, 522), 'right_eye': (619, 514)}, 'face_confidence': np.float64(0.97)}]
# Result: [{'emotion': {'angry': np.float32(0.1559434), 'disgust': np.float32(0.008151874), 'fear': np.float32(0.56556654), 'happy': np.float32(0.006913465), 'sad': np.float32(0.001071726), 'surprise': np.float32(99.26173), 'neutral': np.float32(0.0006272259)}, 'dominant_emotion': 'surprise', 'region': {'x': 554, 'y': 404, 'w': 263, 'h': 263, 'left_eye': (751, 519), 'right_eye': (616, 512)}, 'face_confidence': np.float64(0.96)}, {'emotion': {'angry': np.float32(0.024809761), 'disgust': np.float32(2.6090282e-05), 'fear': np.float32(0.008062405), 'happy': np.float32(84.534225), 'sad': np.float32(0.70927644), 'surprise': np.float32(0.053011946), 'neutral': np.float32(14.670592)}, 'dominant_emotion': 'happy', 'region': {'x': 710, 'y': 479, 'w': 111, 'h': 111, 'left_eye': None, 'right_eye': None}, 'face_confidence': np.float64(0.97)}]
# Result: [{'emotion': {'angry': np.float32(0.0018182851), 'disgust': np.float32(3.17118e-06), 'fear': np.float32(2.6662061), 'happy': np.float32(1.7289698), 'sad': np.float32(6.4315395), 'surprise': np.float32(0.00033465502), 'neutral': np.float32(89.17113)}, 'dominant_emotion': 'neutral', 'region': {'x': 557, 'y': 407, 'w': 259, 'h': 259, 'left_eye': (750, 518), 'right_eye': (660, 598)}, 'face_confidence': np.float64(0.95)}]
# Result: [{'emotion': {'angry': np.float32(0.002262929), 'disgust': np.float32(1.8189768e-07), 'fear': np.float32(79.19246), 'happy': np.float32(0.0019935607), 'sad': np.float32(3.836246e-06), 'surprise': np.float32(20.803278), 'neutral': np.float32(2.3534067e-06)}, 'dominant_emotion': 'fear', 'region': {'x': 544, 'y': 410, 'w': 269, 'h': 269, 'left_eye': (745, 524), 'right_eye': (606, 519)}, 'face_confidence': np.float64(0.95)}]
# Result: [{'emotion': {'angry': np.float32(97.01108), 'disgust': np.float32(0.016198413), 'fear': np.float32(1.1569355), 'happy': np.float32(0.000111681846), 'sad': np.float32(0.0843657), 'surprise': np.float32(1.6785389), 'neutral': np.float32(0.052766163)}, 'dominant_emotion': 'angry', 'region': {'x': 535, 'y': 432, 'w': 277, 'h': 277, 'left_eye': (735, 545), 'right_eye': (602, 544)}, 'face_confidence': np.float64(0.97)}]
# Result: [{'emotion': {'angry': np.float32(0.048745576), 'disgust': np.float32(0.601844), 'fear': np.float32(56.259457), 'happy': np.float32(39.236965), 'sad': np.float32(3.18818), 'surprise': np.float32(0.014754497), 'neutral': np.float32(0.65005475)}, 'dominant_emotion': 'fear', 'region': {'x': 524, 'y': 440, 'w': 277, 'h': 277, 'left_eye': (732, 551), 'right_eye': (592, 554)}, 'face_confidence': np.float64(0.97)}]
# Result: [{'emotion': {'angry': np.float32(0.21986283), 'disgust': np.float32(0.002505695), 'fear': np.float32(92.81278), 'happy': np.float32(0.3944625), 'sad': np.float32(0.00513557), 'surprise': np.float32(6.5635724), 'neutral': np.float32(0.001676069)}, 'dominant_emotion': 'fear', 'region': {'x': 536, 'y': 449, 'w': 268, 'h': 268, 'left_eye': (732, 557), 'right_eye': (592, 561)}, 'face_confidence': np.float64(0.97)}]
# Result: [{'emotion': {'angry': np.float32(0.108951375), 'disgust': np.float32(0.0050767288), 'fear': np.float32(14.872311), 'happy': np.float32(79.18362), 'sad': np.float32(0.10554406), 'surprise': np.float32(5.1465898), 'neutral': np.float32(0.57791865)}, 'dominant_emotion': 'happy', 'region': {'x': 519, 'y': 433, 'w': 292, 'h': 286, 'left_eye': (733, 549), 'right_eye': (589, 551)}, 'face_confidence': np.float64(0.95)}]
# Result: [{'emotion': {'angry': np.float32(0.006163978), 'disgust': np.float32(3.4143502e-06), 'fear': np.float32(64.715034), 'happy': np.float32(21.157423), 'sad': np.float32(0.00040402982), 'surprise': np.float32(14.118589), 'neutral': np.float32(0.0023733133)}, 'dominant_emotion': 'fear', 'region': {'x': 537, 'y': 438, 'w': 279, 'h': 279, 'left_eye': (738, 550), 'right_eye': (590, 549)}, 'face_confidence': np.float64(0.95)}]
# Result: [{'emotion': {'angry': np.float32(0.052164376), 'disgust': np.float32(0.0002245862), 'fear': np.float32(1.4418516), 'happy': np.float32(5.518189), 'sad': np.float32(0.011915678), 'surprise': np.float32(92.964874), 'neutral': np.float32(0.010789308)}, 'dominant_emotion': 'surprise', 'region': {'x': 530, 'y': 438, 'w': 282, 'h': 281, 'left_eye': (737, 552), 'right_eye': (593, 551)}, 'face_confidence': np.float64(0.96)}]
# Result: [{'emotion': {'angry': np.float32(1.0720932), 'disgust': np.float32(6.216624e-05), 'fear': np.float32(67.13402), 'happy': np.float32(2.4031556), 'sad': np.float32(0.0009467354), 'surprise': np.float32(29.38906), 'neutral': np.float32(0.0006616423)}, 'dominant_emotion': 'fear', 'region': {'x': 536, 'y': 438, 'w': 278, 'h': 278, 'left_eye': (735, 548), 'right_eye': (593, 548)}, 'face_confidence': np.float64(0.94)}]
# Result: [{'emotion': {'angry': np.float32(6.82971), 'disgust': np.float32(0.005269985), 'fear': np.float32(80.13208), 'happy': np.float32(0.00036436974), 'sad': np.float32(0.06593972), 'surprise': np.float32(12.96352), 'neutral': np.float32(0.0031078178)}, 'dominant_emotion': 'fear', 'region': {'x': 526, 'y': 428, 'w': 285, 'h': 285, 'left_eye': (736, 546), 'right_eye': (595, 545)}, 'face_confidence': np.float64(0.97)}]
# Result: [{'emotion': {'angry': np.float32(1.6097838), 'disgust': np.float32(0.00012501741), 'fear': np.float32(56.099525), 'happy': np.float32(0.033227537), 'sad': np.float32(0.0037957386), 'surprise': np.float32(42.25301), 'neutral': np.float32(0.0005191592)}, 'dominant_emotion': 'fear', 'region': {'x': 524, 'y': 426, 'w': 288, 'h': 288, 'left_eye': (735, 543), 'right_eye': (599, 544)}, 'face_confidence': np.float64(0.96)}]
# Result: [{'emotion': {'angry': np.float32(2.4997714), 'disgust': np.float32(4.540752e-05), 'fear': np.float32(93.55573), 'happy': np.float32(0.00060075073), 'sad': np.float32(0.018858895), 'surprise': np.float32(3.923024), 'neutral': np.float32(0.0019686082)}, 'dominant_emotion': 'fear', 'region': {'x': 533, 'y': 428, 'w': 283, 'h': 283, 'left_eye': (739, 545), 'right_eye': (601, 543)}, 'face_confidence': np.float64(0.95)}]
# Result: [{'emotion': {'angry': np.float32(0.11496273), 'disgust': np.float32(5.0040498e-08), 'fear': np.float32(98.83272), 'happy': np.float32(0.002389604), 'sad': np.float32(0.00022372603), 'surprise': np.float32(1.0496706), 'neutral': np.float32(2.7094757e-05)}, 'dominant_emotion': 'fear', 'region': {'x': 526, 'y': 433, 'w': 288, 'h': 286, 'left_eye': (737, 547), 'right_eye': (597, 545)}, 'face_confidence': np.float64(0.97)}]
# Result: [{'emotion': {'angry': np.float32(0.00229584), 'disgust': np.float32(1.4830479e-05), 'fear': np.float32(20.320139), 'happy': np.float32(0.0010494535), 'sad': np.float32(0.00074137445), 'surprise': np.float32(79.67564), 'neutral': np.float32(0.0001195221)}, 'dominant_emotion': 'surprise', 'region': {'x': 535, 'y': 442, 'w': 280, 'h': 277, 'left_eye': (737, 551), 'right_eye': (601, 550)}, 'face_confidence': np.float64(0.97)}]
# Result: [{'emotion': {'angry': np.float32(0.08616001), 'disgust': np.float32(1.45396725e-05), 'fear': np.float32(0.7060139), 'happy': np.float32(2.8721559e-05), 'sad': np.float32(0.00014161307), 'surprise': np.float32(99.20764), 'neutral': np.float32(5.603646e-06)}, 'dominant_emotion': 'surprise', 'region': {'x': 532, 'y': 441, 'w': 288, 'h': 278, 'left_eye': (737, 554), 'right_eye': (598, 552)}, 'face_confidence': np.float64(0.97)}]
# Result: [{'emotion': {'angry': np.float32(10.133896), 'disgust': np.float32(0.0014969829), 'fear': np.float32(22.172703), 'happy': np.float32(0.0038065054), 'sad': np.float32(0.014743063), 'surprise': np.float32(67.67037), 'neutral': np.float32(0.0029811943)}, 'dominant_emotion': 'surprise', 'region': {'x': 533, 'y': 441, 'w': 289, 'h': 278, 'left_eye': (738, 559), 'right_eye': (598, 556)}, 'face_confidence': np.float64(0.97)}]
# Result: [{'emotion': {'angry': np.float32(0.0155583555), 'disgust': np.float32(4.2532733e-06), 'fear': np.float32(28.171017), 'happy': np.float32(70.13825), 'sad': np.float32(0.08593071), 'surprise': np.float32(1.4279889), 'neutral': np.float32(0.1612432)}, 'dominant_emotion': 'happy', 'region': {'x': 534, 'y': 436, 'w': 291, 'h': 283, 'left_eye': (739, 560), 'right_eye': (600, 557)}, 'face_confidence': np.float64(0.98)}]
# Result: [{'emotion': {'angry': np.float32(0.010076247), 'disgust': np.float32(0.0001615577), 'fear': np.float32(13.605994), 'happy': np.float32(58.82723), 'sad': np.float32(2.4648275), 'surprise': np.float32(0.57442683), 'neutral': np.float32(24.517286)}, 'dominant_emotion': 'happy', 'region': {'x': 543, 'y': 452, 'w': 273, 'h': 267, 'left_eye': (740, 562), 'right_eye': (600, 560)}, 'face_confidence': np.float64(0.98)}]
# Result: [{'emotion': {'angry': np.float32(0.02647341), 'disgust': np.float32(0.0016427204), 'fear': np.float32(55.015728), 'happy': np.float32(27.140701), 'sad': np.float32(3.9154904), 'surprise': np.float32(0.37961861), 'neutral': np.float32(13.520356)}, 'dominant_emotion': 'fear', 'region': {'x': 529, 'y': 450, 'w': 278, 'h': 269, 'left_eye': (741, 560), 'right_eye': (599, 558)}, 'face_confidence': np.float64(0.97)}]
# Result: [{'emotion': {'angry': np.float32(2.7602284), 'disgust': np.float32(0.060783062), 'fear': np.float32(70.7016), 'happy': np.float32(2.4205842), 'sad': np.float32(0.13086964), 'surprise': np.float32(23.73632), 'neutral': np.float32(0.18961759)}, 'dominant_emotion': 'fear', 'region': {'x': 531, 'y': 442, 'w': 287, 'h': 277, 'left_eye': (740, 561), 'right_eye': (600, 559)}, 'face_confidence': np.float64(0.98)}]
# Result: [{'emotion': {'angry': np.float32(0.0024423038), 'disgust': np.float32(6.3257685e-05), 'fear': np.float32(1.2917348), 'happy': np.float32(92.48003), 'sad': np.float32(0.9712438), 'surprise': np.float32(0.008689425), 'neutral': np.float32(5.245797)}, 'dominant_emotion': 'happy', 'region': {'x': 537, 'y': 452, 'w': 275, 'h': 267, 'left_eye': (739, 565), 'right_eye': (601, 564)}, 'face_confidence': np.float64(0.98)}]
# Result: [{'emotion': {'angry': np.float32(0.026744124), 'disgust': np.float32(6.369442e-10), 'fear': np.float32(0.47746512), 'happy': np.float32(5.9728894), 'sad': np.float32(91.51009), 'surprise': np.float32(0.0007165375), 'neutral': np.float32(2.012095)}, 'dominant_emotion': 'sad', 'region': {'x': 0, 'y': 0, 'w': 1279, 'h': 719, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0}]
# Result: [{'emotion': {'angry': np.float32(0.038326185), 'disgust': np.float32(0.0003490627), 'fear': np.float32(3.8023262), 'happy': np.float32(94.842354), 'sad': np.float32(0.122377865), 'surprise': np.float32(0.060295433), 'neutral': np.float32(1.1339744)}, 'dominant_emotion': 'happy', 'region': {'x': 532, 'y': 452, 'w': 280, 'h': 267, 'left_eye': (738, 572), 'right_eye': (597, 569)}, 'face_confidence': np.float64(0.99)}]
# Result: [{'emotion': {'angry': np.float32(0.4264423), 'disgust': np.float32(0.0005230376), 'fear': np.float32(0.41406456), 'happy': np.float32(23.461086), 'sad': np.float32(0.0072608446), 'surprise': np.float32(75.664474), 'neutral': np.float32(0.026150312)}, 'dominant_emotion': 'surprise', 'region': {'x': 551, 'y': 470, 'w': 261, 'h': 249, 'left_eye': (743, 568), 'right_eye': (596, 567)}, 'face_confidence': np.float64(0.96)}]
# Result: [{'emotion': {'angry': np.float32(0.41330045), 'disgust': np.float32(7.918366e-05), 'fear': np.float32(99.50706), 'happy': np.float32(0.041084394), 'sad': np.float32(0.0033675206), 'surprise': np.float32(0.03493669), 'neutral': np.float32(0.0001772748)}, 'dominant_emotion': 'fear', 'region': {'x': 534, 'y': 445, 'w': 286, 'h': 274, 'left_eye': (732, 562), 'right_eye': (597, 559)}, 'face_confidence': np.float64(0.98)}]
# Result: [{'emotion': {'angry': np.float32(0.8206283), 'disgust': np.float32(3.613978e-05), 'fear': np.float32(16.864338), 'happy': np.float32(0.03813736), 'sad': np.float32(57.69468), 'surprise': np.float32(1.711946), 'neutral': np.float32(22.870234)}, 'dominant_emotion': 'sad', 'region': {'x': 686, 'y': 511, 'w': 124, 'h': 124, 'left_eye': None, 'right_eye': None}, 'face_confidence': np.float64(0.98)}]
# Result: [{'emotion': {'angry': np.float32(0.044658348), 'disgust': np.float32(4.8063453e-10), 'fear': np.float32(1.0440905), 'happy': np.float32(2.6616342), 'sad': np.float32(96.10182), 'surprise': np.float32(7.242442e-05), 'neutral': np.float32(0.14772446)}, 'dominant_emotion': 'sad', 'region': {'x': 0, 'y': 0, 'w': 1279, 'h': 719, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0}]
# Result: [{'emotion': {'angry': np.float32(0.053298675), 'disgust': np.float32(2.6199345e-10), 'fear': np.float32(2.1222358), 'happy': np.float32(4.7290134), 'sad': np.float32(92.99534), 'surprise': np.float32(8.545352e-05), 'neutral': np.float32(0.10002795)}, 'dominant_emotion': 'sad', 'region': {'x': 0, 'y': 0, 'w': 1279, 'h': 719, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0}]
# Result: [{'emotion': {'angry': np.float32(0.059255444), 'disgust': np.float32(2.0977584e-10), 'fear': np.float32(3.2133296), 'happy': np.float32(7.4587345), 'sad': np.float32(89.22799), 'surprise': np.float32(5.7894606e-05), 'neutral': np.float32(0.04063208)}, 'dominant_emotion': 'sad', 'region': {'x': 0, 'y': 0, 'w': 1279, 'h': 719, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0}]
# Result: [{'emotion': {'angry': np.float32(0.30700493), 'disgust': np.float32(2.4130729e-11), 'fear': np.float32(0.15882689), 'happy': np.float32(0.3723333), 'sad': np.float32(3.4249938), 'surprise': np.float32(2.2514037e-07), 'neutral': np.float32(95.73684)}, 'dominant_emotion': 'neutral', 'region': {'x': 499, 'y': 530, 'w': 154, 'h': 154, 'left_eye': None, 'right_eye': None}, 'face_confidence': np.float64(0.97)}]
# Result: [{'emotion': {'angry': np.float32(0.017418785), 'disgust': np.float32(9.824971e-10), 'fear': np.float32(2.5408564), 'happy': np.float32(0.00902253), 'sad': np.float32(2.332826), 'surprise': np.float32(6.604108e-05), 'neutral': np.float32(95.099815)}, 'dominant_emotion': 'neutral', 'region': {'x': 500, 'y': 380, 'w': 322, 'h': 322, 'left_eye': None, 'right_eye': None}, 'face_confidence': np.float64(0.95)}]
# Result: [{'emotion': {'angry': np.float32(16.213476), 'disgust': np.float32(0.00041188506), 'fear': np.float32(14.556853), 'happy': np.float32(0.0027746053), 'sad': np.float32(55.519978), 'surprise': np.float32(0.013601922), 'neutral': np.float32(13.69291)}, 'dominant_emotion': 'sad', 'region': {'x': 473, 'y': 226, 'w': 369, 'h': 369, 'left_eye': (729, 362), 'right_eye': (573, 368)}, 'face_confidence': np.float64(0.92)}]
# Result: [{'emotion': {'angry': np.float32(14.930982), 'disgust': np.float32(0.06302051), 'fear': np.float32(0.7128248), 'happy': np.float32(0.06472385), 'sad': np.float32(0.024206972), 'surprise': np.float32(84.20142), 'neutral': np.float32(0.0028211016)}, 'dominant_emotion': 'surprise', 'region': {'x': 479, 'y': 258, 'w': 364, 'h': 364, 'left_eye': (726, 393), 'right_eye': (571, 398)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(54.229084), 'disgust': np.float32(0.00042016647), 'fear': np.float32(18.987284), 'happy': np.float32(0.17927437), 'sad': np.float32(20.064777), 'surprise': np.float32(2.8075848), 'neutral': np.float32(3.7315817)}, 'dominant_emotion': 'angry', 'region': {'x': 486, 'y': 256, 'w': 354, 'h': 354, 'left_eye': (729, 388), 'right_eye': (576, 393)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(17.742592), 'disgust': np.float32(0.023481555), 'fear': np.float32(8.732141), 'happy': np.float32(0.012101226), 'sad': np.float32(0.22019261), 'surprise': np.float32(73.25989), 'neutral': np.float32(0.009616154)}, 'dominant_emotion': 'surprise', 'region': {'x': 500, 'y': 253, 'w': 358, 'h': 358, 'left_eye': (755, 387), 'right_eye': (598, 384)}, 'face_confidence': np.float64(0.89)}]
# Result: [{'emotion': {'angry': np.float32(0.06836355), 'disgust': np.float32(3.2979062e-06), 'fear': np.float32(11.092087), 'happy': np.float32(1.3302337), 'sad': np.float32(0.04570488), 'surprise': np.float32(81.161156), 'neutral': np.float32(6.3024497)}, 'dominant_emotion': 'surprise', 'region': {'x': 499, 'y': 236, 'w': 367, 'h': 367, 'left_eye': (758, 377), 'right_eye': (600, 376)}, 'face_confidence': np.float64(0.92)}]
# Result: [{'emotion': {'angry': np.float32(1.3833833), 'disgust': np.float32(7.988312e-06), 'fear': np.float32(56.492924), 'happy': np.float32(0.018128732), 'sad': np.float32(0.1487663), 'surprise': np.float32(40.819992), 'neutral': np.float32(1.136792)}, 'dominant_emotion': 'fear', 'region': {'x': 508, 'y': 238, 'w': 352, 'h': 352, 'left_eye': (758, 373), 'right_eye': (604, 371)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(0.06426389), 'disgust': np.float32(1.2976784e-07), 'fear': np.float32(40.061428), 'happy': np.float32(0.01801735), 'sad': np.float32(0.030040015), 'surprise': np.float32(59.48318), 'neutral': np.float32(0.34306827)}, 'dominant_emotion': 'surprise', 'region': {'x': 507, 'y': 232, 'w': 359, 'h': 359, 'left_eye': (764, 367), 'right_eye': (609, 365)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(0.04594197), 'disgust': np.float32(5.472856e-08), 'fear': np.float32(18.628426), 'happy': np.float32(0.0047082137), 'sad': np.float32(0.0034350208), 'surprise': np.float32(81.30884), 'neutral': np.float32(0.008645678)}, 'dominant_emotion': 'surprise', 'region': {'x': 510, 'y': 233, 'w': 362, 'h': 362, 'left_eye': (768, 370), 'right_eye': (612, 366)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(0.0029135027), 'disgust': np.float32(1.3041238e-09), 'fear': np.float32(7.8683887), 'happy': np.float32(0.006279677), 'sad': np.float32(0.00017181151), 'surprise': np.float32(92.117966), 'neutral': np.float32(0.0042777346)}, 'dominant_emotion': 'surprise', 'region': {'x': 511, 'y': 236, 'w': 356, 'h': 356, 'left_eye': (765, 370), 'right_eye': (609, 366)}, 'face_confidence': np.float64(0.89)}]
# Result: [{'emotion': {'angry': np.float32(19.08771), 'disgust': np.float32(4.4773664e-05), 'fear': np.float32(47.55073), 'happy': np.float32(0.017944533), 'sad': np.float32(0.3545657), 'surprise': np.float32(32.42851), 'neutral': np.float32(0.5604975)}, 'dominant_emotion': 'fear', 'region': {'x': 499, 'y': 235, 'w': 365, 'h': 365, 'left_eye': (763, 370), 'right_eye': (608, 366)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(1.267682), 'disgust': np.float32(0.00015629771), 'fear': np.float32(58.74758), 'happy': np.float32(0.06406092), 'sad': np.float32(0.14846194), 'surprise': np.float32(39.72836), 'neutral': np.float32(0.04370119)}, 'dominant_emotion': 'fear', 'region': {'x': 502, 'y': 235, 'w': 361, 'h': 361, 'left_eye': (764, 369), 'right_eye': (608, 367)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(2.4399548), 'disgust': np.float32(4.2506537e-05), 'fear': np.float32(55.133343), 'happy': np.float32(0.01126718), 'sad': np.float32(0.22213058), 'surprise': np.float32(42.179844), 'neutral': np.float32(0.013420477)}, 'dominant_emotion': 'fear', 'region': {'x': 504, 'y': 237, 'w': 358, 'h': 358, 'left_eye': (764, 369), 'right_eye': (607, 366)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(5.052014), 'disgust': np.float32(4.9367754e-06), 'fear': np.float32(26.533783), 'happy': np.float32(0.00025487144), 'sad': np.float32(0.08174887), 'surprise': np.float32(68.3243), 'neutral': np.float32(0.007889777)}, 'dominant_emotion': 'surprise', 'region': {'x': 507, 'y': 239, 'w': 355, 'h': 355, 'left_eye': (762, 367), 'right_eye': (606, 365)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(0.6512015), 'disgust': np.float32(1.9824745e-05), 'fear': np.float32(9.434054), 'happy': np.float32(0.0023138144), 'sad': np.float32(0.008482781), 'surprise': np.float32(89.902626), 'neutral': np.float32(0.0013054215)}, 'dominant_emotion': 'surprise', 'region': {'x': 499, 'y': 235, 'w': 360, 'h': 360, 'left_eye': (760, 367), 'right_eye': (606, 366)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(3.5406778), 'disgust': np.float32(3.63279e-06), 'fear': np.float32(74.12968), 'happy': np.float32(0.00022459784), 'sad': np.float32(0.055540096), 'surprise': np.float32(22.269415), 'neutral': np.float32(0.004461027)}, 'dominant_emotion': 'fear', 'region': {'x': 500, 'y': 236, 'w': 361, 'h': 361, 'left_eye': (762, 368), 'right_eye': (607, 367)}, 'face_confidence': np.float64(0.89)}]
# Result: [{'emotion': {'angry': np.float32(0.012387757), 'disgust': np.float32(1.3087208e-08), 'fear': np.float32(24.603926), 'happy': np.float32(0.05273153), 'sad': np.float32(0.0026310543), 'surprise': np.float32(75.31275), 'neutral': np.float32(0.015572292)}, 'dominant_emotion': 'surprise', 'region': {'x': 502, 'y': 232, 'w': 361, 'h': 361, 'left_eye': (762, 368), 'right_eye': (607, 365)}, 'face_confidence': np.float64(0.9)}, {'emotion': {'angry': np.float32(4.4315004), 'disgust': np.float32(0.0001659183), 'fear': np.float32(17.031025), 'happy': np.float32(0.037408154), 'sad': np.float32(74.35401), 'surprise': np.float32(0.08820637), 'neutral': np.float32(4.0576835)}, 'dominant_emotion': 'sad', 'region': {'x': 0, 'y': 210, 'w': 70, 'h': 70, 'left_eye': None, 'right_eye': None}, 'face_confidence': np.float64(0.97)}]
# Result: [{'emotion': {'angry': np.float32(0.013850114), 'disgust': np.float32(6.6091005e-08), 'fear': np.float32(7.732687), 'happy': np.float32(0.007987992), 'sad': np.float32(0.00022294073), 'surprise': np.float32(92.24477), 'neutral': np.float32(0.00048437214)}, 'dominant_emotion': 'surprise', 'region': {'x': 507, 'y': 235, 'w': 359, 'h': 359, 'left_eye': (758, 371), 'right_eye': (607, 371)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(0.3398112), 'disgust': np.float32(2.2708466e-06), 'fear': np.float32(48.67056), 'happy': np.float32(0.3107966), 'sad': np.float32(0.08057049), 'surprise': np.float32(27.17904), 'neutral': np.float32(23.419222)}, 'dominant_emotion': 'fear', 'region': {'x': 508, 'y': 233, 'w': 360, 'h': 360, 'left_eye': (757, 371), 'right_eye': (606, 372)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(3.352523), 'disgust': np.float32(6.4039473e-06), 'fear': np.float32(76.34216), 'happy': np.float32(0.008124403), 'sad': np.float32(0.12057406), 'surprise': np.float32(19.730293), 'neutral': np.float32(0.44631892)}, 'dominant_emotion': 'fear', 'region': {'x': 502, 'y': 232, 'w': 362, 'h': 362, 'left_eye': (757, 371), 'right_eye': (607, 372)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(4.990291), 'disgust': np.float32(2.4566387e-05), 'fear': np.float32(38.1501), 'happy': np.float32(0.011243724), 'sad': np.float32(0.30415085), 'surprise': np.float32(50.066036), 'neutral': np.float32(6.478153)}, 'dominant_emotion': 'surprise', 'region': {'x': 501, 'y': 230, 'w': 360, 'h': 360, 'left_eye': (758, 369), 'right_eye': (607, 368)}, 'face_confidence': np.float64(0.92)}]
# Result: [{'emotion': {'angry': np.float32(2.5858338), 'disgust': np.float32(6.3385e-05), 'fear': np.float32(1.7527293), 'happy': np.float32(0.0024530026), 'sad': np.float32(0.0056220675), 'surprise': np.float32(95.65175), 'neutral': np.float32(0.0015454864)}, 'dominant_emotion': 'surprise', 'region': {'x': 508, 'y': 230, 'w': 358, 'h': 358, 'left_eye': (760, 364), 'right_eye': (607, 362)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(2.152685), 'disgust': np.float32(3.6720528e-06), 'fear': np.float32(3.812357), 'happy': np.float32(0.00018935904), 'sad': np.float32(0.0019859415), 'surprise': np.float32(94.03277), 'neutral': np.float32(1.7790391e-05)}, 'dominant_emotion': 'surprise', 'region': {'x': 513, 'y': 235, 'w': 349, 'h': 349, 'left_eye': (761, 365), 'right_eye': (608, 362)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(1.5011741), 'disgust': np.float32(6.771824e-06), 'fear': np.float32(6.3052187), 'happy': np.float32(0.00022224052), 'sad': np.float32(0.004381082), 'surprise': np.float32(92.18825), 'neutral': np.float32(0.00074661255)}, 'dominant_emotion': 'surprise', 'region': {'x': 501, 'y': 223, 'w': 366, 'h': 366, 'left_eye': (758, 364), 'right_eye': (605, 361)}, 'face_confidence': np.float64(0.89)}]
# Result: [{'emotion': {'angry': np.float32(88.77703), 'disgust': np.float32(6.62123e-05), 'fear': np.float32(10.329072), 'happy': np.float32(0.0009328597), 'sad': np.float32(0.49806735), 'surprise': np.float32(0.34874535), 'neutral': np.float32(0.04608567)}, 'dominant_emotion': 'angry', 'region': {'x': 505, 'y': 234, 'w': 360, 'h': 360, 'left_eye': (755, 364), 'right_eye': (606, 362)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(84.45654), 'disgust': np.float32(1.6053686e-05), 'fear': np.float32(8.678356), 'happy': np.float32(0.0038804032), 'sad': np.float32(3.795027), 'surprise': np.float32(0.5183002), 'neutral': np.float32(2.5478785)}, 'dominant_emotion': 'angry', 'region': {'x': 502, 'y': 235, 'w': 364, 'h': 364, 'left_eye': (756, 370), 'right_eye': (608, 367)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(46.335735), 'disgust': np.float32(0.000375754), 'fear': np.float32(10.860406), 'happy': np.float32(0.0051906523), 'sad': np.float32(27.504778), 'surprise': np.float32(0.55832636), 'neutral': np.float32(14.7351885)}, 'dominant_emotion': 'angry', 'region': {'x': 507, 'y': 239, 'w': 361, 'h': 361, 'left_eye': (756, 372), 'right_eye': (607, 368)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(94.54122), 'disgust': np.float32(0.0066389143), 'fear': np.float32(0.62808794), 'happy': np.float32(0.0011597662), 'sad': np.float32(0.04068085), 'surprise': np.float32(4.7694793), 'neutral': np.float32(0.012730089)}, 'dominant_emotion': 'angry', 'region': {'x': 493, 'y': 229, 'w': 379, 'h': 379, 'left_eye': (758, 373), 'right_eye': (608, 370)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(0.757768), 'disgust': np.float32(2.7605097e-07), 'fear': np.float32(5.2436967), 'happy': np.float32(4.7905218e-05), 'sad': np.float32(12.12852), 'surprise': np.float32(0.006089916), 'neutral': np.float32(81.86388)}, 'dominant_emotion': 'neutral', 'region': {'x': 495, 'y': 227, 'w': 375, 'h': 375, 'left_eye': (758, 367), 'right_eye': (606, 365)}, 'face_confidence': np.float64(0.89)}]
# Result: [{'emotion': {'angry': np.float32(94.768715), 'disgust': np.float32(1.15763705e-05), 'fear': np.float32(1.0905695), 'happy': np.float32(0.0007833367), 'sad': np.float32(0.07580882), 'surprise': np.float32(3.983001), 'neutral': np.float32(0.081108876)}, 'dominant_emotion': 'angry', 'region': {'x': 503, 'y': 234, 'w': 369, 'h': 369, 'left_eye': (759, 368), 'right_eye': (607, 365)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(72.09167), 'disgust': np.float32(0.00038337338), 'fear': np.float32(0.17438416), 'happy': np.float32(0.00028457984), 'sad': np.float32(0.019497948), 'surprise': np.float32(27.71283), 'neutral': np.float32(0.0009566349)}, 'dominant_emotion': 'angry', 'region': {'x': 501, 'y': 235, 'w': 366, 'h': 366, 'left_eye': (758, 371), 'right_eye': (607, 368)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(71.75555), 'disgust': np.float32(0.0035153695), 'fear': np.float32(0.046789777), 'happy': np.float32(0.00010996551), 'sad': np.float32(0.002517456), 'surprise': np.float32(28.191507), 'neutral': np.float32(1.5924892e-05)}, 'dominant_emotion': 'angry', 'region': {'x': 498, 'y': 234, 'w': 368, 'h': 368, 'left_eye': (756, 371), 'right_eye': (607, 370)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(4.7955723), 'disgust': np.float32(0.002114075), 'fear': np.float32(1.0431204), 'happy': np.float32(0.00053281186), 'sad': np.float32(0.0048604743), 'surprise': np.float32(94.15377), 'neutral': np.float32(3.187503e-05)}, 'dominant_emotion': 'surprise', 'region': {'x': 492, 'y': 228, 'w': 382, 'h': 382, 'left_eye': (757, 372), 'right_eye': (606, 368)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(9.363503), 'disgust': np.float32(4.24631e-07), 'fear': np.float32(5.005211), 'happy': np.float32(4.023563e-05), 'sad': np.float32(17.727823), 'surprise': np.float32(0.0044552973), 'neutral': np.float32(67.89897)}, 'dominant_emotion': 'neutral', 'region': {'x': 497, 'y': 230, 'w': 371, 'h': 371, 'left_eye': (757, 366), 'right_eye': (607, 364)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(28.608923), 'disgust': np.float32(4.4607415e-05), 'fear': np.float32(25.979538), 'happy': np.float32(0.0010475757), 'sad': np.float32(3.724047), 'surprise': np.float32(6.5893903), 'neutral': np.float32(35.09701)}, 'dominant_emotion': 'neutral', 'region': {'x': 509, 'y': 235, 'w': 356, 'h': 356, 'left_eye': (759, 366), 'right_eye': (609, 364)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(0.7107439), 'disgust': np.float32(1.5146455e-05), 'fear': np.float32(3.8089159), 'happy': np.float32(0.005535437), 'sad': np.float32(3.9669275), 'surprise': np.float32(1.1553127), 'neutral': np.float32(90.352554)}, 'dominant_emotion': 'neutral', 'region': {'x': 505, 'y': 231, 'w': 364, 'h': 364, 'left_eye': (760, 368), 'right_eye': (610, 364)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(5.420877), 'disgust': np.float32(5.2674273e-05), 'fear': np.float32(14.412049), 'happy': np.float32(0.007022397), 'sad': np.float32(7.9751487), 'surprise': np.float32(2.555595), 'neutral': np.float32(69.62926)}, 'dominant_emotion': 'neutral', 'region': {'x': 508, 'y': 232, 'w': 360, 'h': 360, 'left_eye': (761, 367), 'right_eye': (612, 364)}, 'face_confidence': np.float64(0.89)}]
# Result: [{'emotion': {'angry': np.float32(1.1946661), 'disgust': np.float32(1.4167405e-06), 'fear': np.float32(1.3711251), 'happy': np.float32(0.0029165696), 'sad': np.float32(2.9556854), 'surprise': np.float32(0.24080604), 'neutral': np.float32(94.2348)}, 'dominant_emotion': 'neutral', 'region': {'x': 514, 'y': 235, 'w': 352, 'h': 352, 'left_eye': (762, 369), 'right_eye': (610, 365)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(0.04432768), 'disgust': np.float32(1.5035129e-10), 'fear': np.float32(95.44434), 'happy': np.float32(3.97907), 'sad': np.float32(0.00343975), 'surprise': np.float32(0.44838932), 'neutral': np.float32(0.08043311)}, 'dominant_emotion': 'fear', 'region': {'x': 0, 'y': 0, 'w': 1279, 'h': 719, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0}]
# Result: [{'emotion': {'angry': np.float32(43.494377), 'disgust': np.float32(0.0019670594), 'fear': np.float32(11.160748), 'happy': np.float32(0.059551015), 'sad': np.float32(2.2958963), 'surprise': np.float32(30.068552), 'neutral': np.float32(12.918907)}, 'dominant_emotion': 'angry', 'region': {'x': 515, 'y': 237, 'w': 352, 'h': 352, 'left_eye': (760, 368), 'right_eye': (610, 364)}, 'face_confidence': np.float64(0.89)}]
# Result: [{'emotion': {'angry': np.float32(0.9742631), 'disgust': np.float32(1.17704005e-07), 'fear': np.float32(0.5220801), 'happy': np.float32(0.0035376376), 'sad': np.float32(3.7008598), 'surprise': np.float32(0.030502584), 'neutral': np.float32(94.76875)}, 'dominant_emotion': 'neutral', 'region': {'x': 517, 'y': 237, 'w': 349, 'h': 349, 'left_eye': (760, 368), 'right_eye': (610, 364)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(97.40993), 'disgust': np.float32(8.300979e-05), 'fear': np.float32(0.117826164), 'happy': np.float32(0.002963907), 'sad': np.float32(0.4023505), 'surprise': np.float32(1.8214074), 'neutral': np.float32(0.24543446)}, 'dominant_emotion': 'angry', 'region': {'x': 507, 'y': 239, 'w': 355, 'h': 355, 'left_eye': (759, 374), 'right_eye': (612, 370)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(68.07377), 'disgust': np.float32(0.0015033882), 'fear': np.float32(1.4294657), 'happy': np.float32(0.011686128), 'sad': np.float32(0.423849), 'surprise': np.float32(29.85682), 'neutral': np.float32(0.20290352)}, 'dominant_emotion': 'angry', 'region': {'x': 507, 'y': 239, 'w': 356, 'h': 356, 'left_eye': (760, 374), 'right_eye': (610, 370)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(29.592518), 'disgust': np.float32(0.00070866593), 'fear': np.float32(20.905796), 'happy': np.float32(0.013864985), 'sad': np.float32(13.784836), 'surprise': np.float32(1.1206422), 'neutral': np.float32(34.58164)}, 'dominant_emotion': 'neutral', 'region': {'x': 506, 'y': 233, 'w': 360, 'h': 360, 'left_eye': (759, 369), 'right_eye': (609, 366)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(52.871334), 'disgust': np.float32(0.00016762044), 'fear': np.float32(3.9235725), 'happy': np.float32(0.032598764), 'sad': np.float32(14.011047), 'surprise': np.float32(0.67102104), 'neutral': np.float32(28.490257)}, 'dominant_emotion': 'angry', 'region': {'x': 514, 'y': 237, 'w': 352, 'h': 352, 'left_eye': (760, 368), 'right_eye': (610, 365)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(7.7622523), 'disgust': np.float32(0.00016590527), 'fear': np.float32(3.8175204), 'happy': np.float32(0.015688239), 'sad': np.float32(5.048503), 'surprise': np.float32(5.176322), 'neutral': np.float32(78.17955)}, 'dominant_emotion': 'neutral', 'region': {'x': 510, 'y': 233, 'w': 356, 'h': 356, 'left_eye': (762, 368), 'right_eye': (611, 364)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(57.388714), 'disgust': np.float32(0.0003954835), 'fear': np.float32(7.220318), 'happy': np.float32(0.005861589), 'sad': np.float32(2.2136073), 'surprise': np.float32(31.683533), 'neutral': np.float32(1.4875722)}, 'dominant_emotion': 'angry', 'region': {'x': 509, 'y': 236, 'w': 356, 'h': 356, 'left_eye': (762, 368), 'right_eye': (612, 364)}, 'face_confidence': np.float64(0.89)}]
# Result: [{'emotion': {'angry': np.float32(65.22631), 'disgust': np.float32(6.517947e-05), 'fear': np.float32(6.02689), 'happy': np.float32(0.0022082583), 'sad': np.float32(20.01045), 'surprise': np.float32(0.056694053), 'neutral': np.float32(8.677386)}, 'dominant_emotion': 'angry', 'region': {'x': 508, 'y': 240, 'w': 358, 'h': 358, 'left_eye': (761, 371), 'right_eye': (613, 367)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(65.84744), 'disgust': np.float32(0.0005489434), 'fear': np.float32(0.8188912), 'happy': np.float32(0.002987138), 'sad': np.float32(0.5708509), 'surprise': np.float32(32.333946), 'neutral': np.float32(0.4253449)}, 'dominant_emotion': 'angry', 'region': {'x': 510, 'y': 239, 'w': 355, 'h': 355, 'left_eye': (760, 373), 'right_eye': (612, 369)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(95.92393), 'disgust': np.float32(0.000149564), 'fear': np.float32(0.49204347), 'happy': np.float32(0.0030312834), 'sad': np.float32(0.6939914), 'surprise': np.float32(2.5964854), 'neutral': np.float32(0.2903746)}, 'dominant_emotion': 'angry', 'region': {'x': 508, 'y': 237, 'w': 358, 'h': 358, 'left_eye': (762, 371), 'right_eye': (612, 367)}, 'face_confidence': np.float64(0.92)}]
# Result: [{'emotion': {'angry': np.float32(80.04165), 'disgust': np.float32(0.00037439613), 'fear': np.float32(0.36369154), 'happy': np.float32(0.000610152), 'sad': np.float32(0.059031077), 'surprise': np.float32(19.523138), 'neutral': np.float32(0.0115129445)}, 'dominant_emotion': 'angry', 'region': {'x': 511, 'y': 236, 'w': 355, 'h': 355, 'left_eye': (761, 366), 'right_eye': (614, 364)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(29.477886), 'disgust': np.float32(0.0002399049), 'fear': np.float32(19.5115), 'happy': np.float32(0.024076005), 'sad': np.float32(5.5365787), 'surprise': np.float32(17.763338), 'neutral': np.float32(27.686384)}, 'dominant_emotion': 'angry', 'region': {'x': 510, 'y': 239, 'w': 354, 'h': 354, 'left_eye': (762, 367), 'right_eye': (614, 363)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(55.99783), 'disgust': np.float32(0.00023721182), 'fear': np.float32(4.749258), 'happy': np.float32(0.0006162273), 'sad': np.float32(29.404814), 'surprise': np.float32(0.011000341), 'neutral': np.float32(9.836245)}, 'dominant_emotion': 'angry', 'region': {'x': 508, 'y': 240, 'w': 355, 'h': 355, 'left_eye': (759, 372), 'right_eye': (611, 369)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(92.71795), 'disgust': np.float32(8.682567e-05), 'fear': np.float32(0.46724015), 'happy': np.float32(0.00093734806), 'sad': np.float32(4.693505), 'surprise': np.float32(0.59330535), 'neutral': np.float32(1.5269818)}, 'dominant_emotion': 'angry', 'region': {'x': 504, 'y': 236, 'w': 361, 'h': 361, 'left_eye': (759, 373), 'right_eye': (612, 369)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(83.60673), 'disgust': np.float32(1.9855956e-06), 'fear': np.float32(1.4560539), 'happy': np.float32(0.0040706964), 'sad': np.float32(5.364676), 'surprise': np.float32(0.7703013), 'neutral': np.float32(8.798179)}, 'dominant_emotion': 'angry', 'region': {'x': 512, 'y': 235, 'w': 356, 'h': 356, 'left_eye': (761, 364), 'right_eye': (610, 362)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(26.24895), 'disgust': np.float32(5.1325733e-06), 'fear': np.float32(12.506217), 'happy': np.float32(0.00485036), 'sad': np.float32(1.7887013), 'surprise': np.float32(45.486595), 'neutral': np.float32(13.96468)}, 'dominant_emotion': 'surprise', 'region': {'x': 515, 'y': 227, 'w': 347, 'h': 347, 'left_eye': (758, 355), 'right_eye': (608, 351)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(69.75287), 'disgust': np.float32(9.0893167e-07), 'fear': np.float32(8.285055), 'happy': np.float32(8.079883e-05), 'sad': np.float32(21.83923), 'surprise': np.float32(0.0091396645), 'neutral': np.float32(0.1136309)}, 'dominant_emotion': 'angry', 'region': {'x': 510, 'y': 218, 'w': 358, 'h': 358, 'left_eye': (758, 350), 'right_eye': (609, 347)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(92.62489), 'disgust': np.float32(5.0184997e-05), 'fear': np.float32(4.2749486), 'happy': np.float32(0.0061665773), 'sad': np.float32(2.514989), 'surprise': np.float32(0.49983534), 'neutral': np.float32(0.07911871)}, 'dominant_emotion': 'angry', 'region': {'x': 506, 'y': 215, 'w': 360, 'h': 360, 'left_eye': (755, 349), 'right_eye': (605, 345)}, 'face_confidence': np.float64(0.92)}]
# Result: [{'emotion': {'angry': np.float32(94.39472), 'disgust': np.float32(1.1010162e-07), 'fear': np.float32(0.7245512), 'happy': np.float32(1.2783332e-05), 'sad': np.float32(4.8651943), 'surprise': np.float32(0.0006398305), 'neutral': np.float32(0.01487603)}, 'dominant_emotion': 'angry', 'region': {'x': 507, 'y': 215, 'w': 361, 'h': 361, 'left_eye': (756, 350), 'right_eye': (605, 346)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(82.5111), 'disgust': np.float32(3.0039155e-06), 'fear': np.float32(12.524639), 'happy': np.float32(0.0007935713), 'sad': np.float32(4.0870543), 'surprise': np.float32(0.462558), 'neutral': np.float32(0.41384757)}, 'dominant_emotion': 'angry', 'region': {'x': 507, 'y': 216, 'w': 358, 'h': 358, 'left_eye': (756, 350), 'right_eye': (606, 347)}, 'face_confidence': np.float64(0.93)}]
# Result: [{'emotion': {'angry': np.float32(67.77159), 'disgust': np.float32(0.00015413057), 'fear': np.float32(25.199852), 'happy': np.float32(0.0025082016), 'sad': np.float32(6.1590557), 'surprise': np.float32(0.85171574), 'neutral': np.float32(0.0151238665)}, 'dominant_emotion': 'angry', 'region': {'x': 508, 'y': 217, 'w': 362, 'h': 362, 'left_eye': (756, 351), 'right_eye': (607, 346)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(24.059464), 'disgust': np.float32(0.0012387672), 'fear': np.float32(8.987851), 'happy': np.float32(0.3542123), 'sad': np.float32(47.80811), 'surprise': np.float32(0.19774914), 'neutral': np.float32(18.591373)}, 'dominant_emotion': 'sad', 'region': {'x': 508, 'y': 235, 'w': 374, 'h': 374, 'left_eye': (770, 379), 'right_eye': (622, 372)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(26.161268), 'disgust': np.float32(0.013509176), 'fear': np.float32(20.37214), 'happy': np.float32(0.17122142), 'sad': np.float32(15.825042), 'surprise': np.float32(2.616332), 'neutral': np.float32(34.840492)}, 'dominant_emotion': 'neutral', 'region': {'x': 521, 'y': 245, 'w': 364, 'h': 364, 'left_eye': (776, 383), 'right_eye': (623, 376)}, 'face_confidence': np.float64(0.92)}]
# Result: [{'emotion': {'angry': np.float32(25.712742), 'disgust': np.float32(0.00019139139), 'fear': np.float32(20.910284), 'happy': np.float32(0.0070098615), 'sad': np.float32(2.32613), 'surprise': np.float32(45.966934), 'neutral': np.float32(5.076707)}, 'dominant_emotion': 'surprise', 'region': {'x': 516, 'y': 235, 'w': 361, 'h': 361, 'left_eye': (769, 368), 'right_eye': (617, 362)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(23.548252), 'disgust': np.float32(0.00019551473), 'fear': np.float32(11.206722), 'happy': np.float32(0.13538456), 'sad': np.float32(1.0967954), 'surprise': np.float32(50.74356), 'neutral': np.float32(13.269086)}, 'dominant_emotion': 'surprise', 'region': {'x': 513, 'y': 237, 'w': 358, 'h': 358, 'left_eye': (770, 367), 'right_eye': (620, 362)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(16.70423), 'disgust': np.float32(0.00079329783), 'fear': np.float32(74.12081), 'happy': np.float32(0.013695257), 'sad': np.float32(0.83844745), 'surprise': np.float32(7.8635006), 'neutral': np.float32(0.45851868)}, 'dominant_emotion': 'fear', 'region': {'x': 512, 'y': 236, 'w': 364, 'h': 364, 'left_eye': (766, 372), 'right_eye': (617, 365)}, 'face_confidence': np.float64(0.92)}]
# Result: [{'emotion': {'angry': np.float32(21.792013), 'disgust': np.float32(4.4339216e-05), 'fear': np.float32(6.4231334), 'happy': np.float32(0.044090714), 'sad': np.float32(5.573686), 'surprise': np.float32(50.98515), 'neutral': np.float32(15.181888)}, 'dominant_emotion': 'surprise', 'region': {'x': 515, 'y': 238, 'w': 353, 'h': 353, 'left_eye': (767, 371), 'right_eye': (616, 366)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(17.429972), 'disgust': np.float32(0.00028559557), 'fear': np.float32(0.31521934), 'happy': np.float32(0.006272135), 'sad': np.float32(0.080562), 'surprise': np.float32(82.124245), 'neutral': np.float32(0.04345366)}, 'dominant_emotion': 'surprise', 'region': {'x': 512, 'y': 236, 'w': 359, 'h': 359, 'left_eye': (766, 371), 'right_eye': (613, 365)}, 'face_confidence': np.float64(0.92)}]
# Result: [{'emotion': {'angry': np.float32(12.374983), 'disgust': np.float32(8.478604e-05), 'fear': np.float32(16.979862), 'happy': np.float32(0.03147778), 'sad': np.float32(24.457022), 'surprise': np.float32(2.8044949), 'neutral': np.float32(43.35208)}, 'dominant_emotion': 'neutral', 'region': {'x': 514, 'y': 241, 'w': 351, 'h': 351, 'left_eye': (761, 370), 'right_eye': (612, 366)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(13.428815), 'disgust': np.float32(0.0003483259), 'fear': np.float32(17.136036), 'happy': np.float32(0.0010193014), 'sad': np.float32(49.937683), 'surprise': np.float32(0.07171261), 'neutral': np.float32(19.424385)}, 'dominant_emotion': 'sad', 'region': {'x': 501, 'y': 236, 'w': 371, 'h': 371, 'left_eye': (760, 375), 'right_eye': (610, 371)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(91.50746), 'disgust': np.float32(0.0213167), 'fear': np.float32(1.654667), 'happy': np.float32(0.013328865), 'sad': np.float32(2.0531805), 'surprise': np.float32(3.6282735), 'neutral': np.float32(1.1217823)}, 'dominant_emotion': 'angry', 'region': {'x': 505, 'y': 233, 'w': 369, 'h': 369, 'left_eye': (761, 371), 'right_eye': (610, 368)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(10.1991005), 'disgust': np.float32(0.00010843813), 'fear': np.float32(5.5170407), 'happy': np.float32(0.0031007633), 'sad': np.float32(0.02789314), 'surprise': np.float32(84.21204), 'neutral': np.float32(0.040712185)}, 'dominant_emotion': 'surprise', 'region': {'x': 518, 'y': 239, 'w': 348, 'h': 348, 'left_eye': (766, 367), 'right_eye': (610, 364)}, 'face_confidence': np.float64(0.88)}]
# Result: [{'emotion': {'angry': np.float32(2.6672184), 'disgust': np.float32(0.0005072699), 'fear': np.float32(4.3295813), 'happy': np.float32(0.0036789258), 'sad': np.float32(0.0654394), 'surprise': np.float32(92.92973), 'neutral': np.float32(0.0038454968)}, 'dominant_emotion': 'surprise', 'region': {'x': 510, 'y': 239, 'w': 352, 'h': 352, 'left_eye': (763, 370), 'right_eye': (608, 367)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(54.41), 'disgust': np.float32(0.005471481), 'fear': np.float32(28.564463), 'happy': np.float32(0.027373549), 'sad': np.float32(1.7142766), 'surprise': np.float32(11.664883), 'neutral': np.float32(3.6135309)}, 'dominant_emotion': 'angry', 'region': {'x': 513, 'y': 235, 'w': 351, 'h': 351, 'left_eye': (766, 366), 'right_eye': (608, 363)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(34.41166), 'disgust': np.float32(0.0026839594), 'fear': np.float32(10.21323), 'happy': np.float32(0.12407941), 'sad': np.float32(3.6478534), 'surprise': np.float32(50.507626), 'neutral': np.float32(1.092871)}, 'dominant_emotion': 'surprise', 'region': {'x': 507, 'y': 230, 'w': 364, 'h': 364, 'left_eye': (762, 364), 'right_eye': (608, 361)}, 'face_confidence': np.float64(0.9)}]
# Result: [{'emotion': {'angry': np.float32(12.09942), 'disgust': np.float32(0.005886278), 'fear': np.float32(70.024864), 'happy': np.float32(0.08723719), 'sad': np.float32(1.4838632), 'surprise': np.float32(11.24356), 'neutral': np.float32(5.055176)}, 'dominant_emotion': 'fear', 'region': {'x': 504, 'y': 227, 'w': 364, 'h': 364, 'left_eye': (762, 364), 'right_eye': (606, 361)}, 'face_confidence': np.float64(0.9)}]
# ...
# Result: [{'emotion': {'angry': np.float32(0.65017575), 'disgust': np.float32(1.2915668e-06), 'fear': np.float32(9.511005), 'happy': np.float32(0.0049763964), 'sad': np.float32(0.0018346744), 'surprise': np.float32(89.80378), 'neutral': np.float32(0.028228931)}, 'dominant_emotion': 'surprise', 'region': {'x': 511, 'y': 228, 'w': 358, 'h': 358, 'left_eye': (759, 362), 'right_eye': (609, 359)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(88.01185), 'disgust': np.float32(0.0046107625), 'fear': np.float32(0.33543423), 'happy': np.float32(0.0005797873), 'sad': np.float32(0.010182199), 'surprise': np.float32(11.637284), 'neutral': np.float32(5.7095007e-05)}, 'dominant_emotion': 'angry', 'region': {'x': 502, 'y': 229, 'w': 369, 'h': 369, 'left_eye': (756, 364), 'right_eye': (607, 363)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(16.18412), 'disgust': np.float32(3.9055703e-06), 'fear': np.float32(35.989468), 'happy': np.float32(0.00068879564), 'sad': np.float32(22.44444), 'surprise': np.float32(0.06119052), 'neutral': np.float32(25.320095)}, 'dominant_emotion': 'fear', 'region': {'x': 499, 'y': 233, 'w': 371, 'h': 371, 'left_eye': (756, 368), 'right_eye': (606, 365)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(81.41935), 'disgust': np.float32(0.07688229), 'fear': np.float32(0.14593285), 'happy': np.float32(0.0006677229), 'sad': np.float32(0.01562836), 'surprise': np.float32(18.34089), 'neutral': np.float32(0.0006477942)}, 'dominant_emotion': 'angry', 'region': {'x': 499, 'y': 230, 'w': 368, 'h': 368, 'left_eye': (753, 367), 'right_eye': (604, 365)}, 'face_confidence': np.float64(0.92)}]
# Result: [{'emotion': {'angry': np.float32(75.42645), 'disgust': np.float32(3.1059895e-05), 'fear': np.float32(14.480504), 'happy': np.float32(0.0040457817), 'sad': np.float32(0.44388968), 'surprise': np.float32(9.383125), 'neutral': np.float32(0.26195621)}, 'dominant_emotion': 'angry', 'region': {'x': 499, 'y': 232, 'w': 366, 'h': 366, 'left_eye': (752, 367), 'right_eye': (600, 365)}, 'face_confidence': np.float64(0.92)}]
# Result: [{'emotion': {'angry': np.float32(0.04911977), 'disgust': np.float32(8.960008e-05), 'fear': np.float32(27.227882), 'happy': np.float32(0.025383094), 'sad': np.float32(70.517914), 'surprise': np.float32(0.0023395433), 'neutral': np.float32(2.177273)}, 'dominant_emotion': 'sad', 'region': {'x': 493, 'y': 233, 'w': 372, 'h': 372, 'left_eye': (753, 372), 'right_eye': (654, 473)}, 'face_confidence': np.float64(0.93)}]
# Result: [{'emotion': {'angry': np.float32(23.91226), 'disgust': np.float32(1.108124e-06), 'fear': np.float32(0.4795116), 'happy': np.float32(0.0018395205), 'sad': np.float32(16.026745), 'surprise': np.float32(0.37532735), 'neutral': np.float32(59.204323)}, 'dominant_emotion': 'neutral', 'region': {'x': 504, 'y': 231, 'w': 361, 'h': 361, 'left_eye': (753, 367), 'right_eye': (603, 365)}, 'face_confidence': np.float64(0.92)}]
# Result: [{'emotion': {'angry': np.float32(77.628365), 'disgust': np.float32(0.00019260366), 'fear': np.float32(3.6243744), 'happy': np.float32(0.005495191), 'sad': np.float32(5.188354), 'surprise': np.float32(4.858401), 'neutral': np.float32(8.694826)}, 'dominant_emotion': 'angry', 'region': {'x': 498, 'y': 229, 'w': 365, 'h': 365, 'left_eye': (751, 366), 'right_eye': (601, 365)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(96.53), 'disgust': np.float32(0.0021257142), 'fear': np.float32(0.07680703), 'happy': np.float32(0.00026525516), 'sad': np.float32(0.039287016), 'surprise': np.float32(3.347087), 'neutral': np.float32(0.0044329898)}, 'dominant_emotion': 'angry', 'region': {'x': 495, 'y': 229, 'w': 368, 'h': 368, 'left_eye': (751, 366), 'right_eye': (600, 365)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(92.04001), 'disgust': np.float32(0.0015260954), 'fear': np.float32(0.2754417), 'happy': np.float32(0.00048799414), 'sad': np.float32(0.026818175), 'surprise': np.float32(7.6533904), 'neutral': np.float32(0.0023310203)}, 'dominant_emotion': 'angry', 'region': {'x': 497, 'y': 230, 'w': 367, 'h': 367, 'left_eye': (752, 366), 'right_eye': (601, 366)}, 'face_confidence': np.float64(0.93)}]
# Result: [{'emotion': {'angry': np.float32(19.5069), 'disgust': np.float32(4.0905416e-05), 'fear': np.float32(11.434771), 'happy': np.float32(0.00088006654), 'sad': np.float32(36.289753), 'surprise': np.float32(0.037701845), 'neutral': np.float32(32.729954)}, 'dominant_emotion': 'sad', 'region': {'x': 502, 'y': 235, 'w': 358, 'h': 358, 'left_eye': (752, 366), 'right_eye': (602, 364)}, 'face_confidence': np.float64(0.92)}]
# Result: [{'emotion': {'angry': np.float32(80.97585), 'disgust': np.float32(1.350604e-07), 'fear': np.float32(2.0168097), 'happy': np.float32(7.989905e-05), 'sad': np.float32(13.628344), 'surprise': np.float32(0.014627034), 'neutral': np.float32(3.364296)}, 'dominant_emotion': 'angry', 'region': {'x': 500, 'y': 231, 'w': 364, 'h': 364, 'left_eye': (749, 364), 'right_eye': (602, 364)}, 'face_confidence': np.float64(0.92)}]
# Result: [{'emotion': {'angry': np.float32(70.06247), 'disgust': np.float32(7.5969016e-05), 'fear': np.float32(1.0511826), 'happy': np.float32(0.002576515), 'sad': np.float32(0.6941892), 'surprise': np.float32(27.739912), 'neutral': np.float32(0.44959635)}, 'dominant_emotion': 'angry', 'region': {'x': 501, 'y': 232, 'w': 359, 'h': 359, 'left_eye': (749, 364), 'right_eye': (601, 363)}, 'face_confidence': np.float64(0.92)}]
# Result: [{'emotion': {'angry': np.float32(72.053505), 'disgust': np.float32(0.03584248), 'fear': np.float32(17.308607), 'happy': np.float32(0.00928167), 'sad': np.float32(0.8662617), 'surprise': np.float32(9.198863), 'neutral': np.float32(0.52764684)}, 'dominant_emotion': 'angry', 'region': {'x': 501, 'y': 229, 'w': 359, 'h': 359, 'left_eye': (752, 362), 'right_eye': (601, 361)}, 'face_confidence': np.float64(0.92)}]
# Result: [{'emotion': {'angry': np.float32(71.95022), 'disgust': np.float32(1.4072663e-06), 'fear': np.float32(4.5371537), 'happy': np.float32(0.00018699073), 'sad': np.float32(17.751846), 'surprise': np.float32(0.0040241648), 'neutral': np.float32(5.756574)}, 'dominant_emotion': 'angry', 'region': {'x': 502, 'y': 229, 'w': 361, 'h': 361, 'left_eye': (753, 359), 'right_eye': (605, 359)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(9.415175), 'disgust': np.float32(1.7631658e-06), 'fear': np.float32(11.82908), 'happy': np.float32(0.0003238993), 'sad': np.float32(5.896325), 'surprise': np.float32(1.410504), 'neutral': np.float32(71.44859)}, 'dominant_emotion': 'neutral', 'region': {'x': 503, 'y': 230, 'w': 358, 'h': 358, 'left_eye': (756, 359), 'right_eye': (604, 357)}, 'face_confidence': np.float64(0.92)}]
# Result: [{'emotion': {'angry': np.float32(97.93658), 'disgust': np.float32(1.5668715e-05), 'fear': np.float32(0.112906724), 'happy': np.float32(6.931542e-05), 'sad': np.float32(1.3811904), 'surprise': np.float32(0.045705404), 'neutral': np.float32(0.52352)}, 'dominant_emotion': 'angry', 'region': {'x': 510, 'y': 226, 'w': 360, 'h': 360, 'left_eye': (756, 358), 'right_eye': (608, 355)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(67.51095), 'disgust': np.float32(0.0140010975), 'fear': np.float32(7.828991), 'happy': np.float32(0.0044932966), 'sad': np.float32(0.20915619), 'surprise': np.float32(24.373194), 'neutral': np.float32(0.05921857)}, 'dominant_emotion': 'angry', 'region': {'x': 507, 'y': 224, 'w': 358, 'h': 358, 'left_eye': (758, 358), 'right_eye': (608, 354)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(13.504116), 'disgust': np.float32(5.653626e-06), 'fear': np.float32(21.22139), 'happy': np.float32(0.0035774815), 'sad': np.float32(10.993346), 'surprise': np.float32(3.9927163), 'neutral': np.float32(50.284855)}, 'dominant_emotion': 'neutral', 'region': {'x': 508, 'y': 228, 'w': 354, 'h': 354, 'left_eye': (757, 359), 'right_eye': (607, 357)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(94.64086), 'disgust': np.float32(3.5791345e-06), 'fear': np.float32(0.22293606), 'happy': np.float32(0.00011640156), 'sad': np.float32(1.1218415), 'surprise': np.float32(0.95872587), 'neutral': np.float32(3.0555086)}, 'dominant_emotion': 'angry', 'region': {'x': 506, 'y': 226, 'w': 356, 'h': 356, 'left_eye': (756, 358), 'right_eye': (608, 356)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(47.706223), 'disgust': np.float32(0.0028808352), 'fear': np.float32(42.270603), 'happy': np.float32(0.0037311364), 'sad': np.float32(8.054675), 'surprise': np.float32(0.90220505), 'neutral': np.float32(1.0596873)}, 'dominant_emotion': 'angry', 'region': {'x': 502, 'y': 228, 'w': 356, 'h': 356, 'left_eye': (754, 357), 'right_eye': (603, 354)}, 'face_confidence': np.float64(0.91)}]
# Result: [{'emotion': {'angry': np.float32(15.030001), 'disgust': np.float32(5.031616e-06), 'fear': np.float32(8.209064), 'happy': np.float32(0.005545623), 'sad': np.float32(21.114311), 'surprise': np.float32(1.4465905), 'neutral': np.float32(54.194485)}, 'dominant_emotion': 'neutral', 'region': {'x': 514, 'y': 230, 'w': 342, 'h': 342, 'left_eye': (753, 355), 'right_eye': (603, 353)}, 'face_confidence': np.float64(0.89)}]
# Result: [{'emotion': {'angry': np.float32(73.69998), 'disgust': np.float32(4.163794e-05), 'fear': np.float32(1.3105098), 'happy': np.float32(0.0006081918), 'sad': np.float32(0.22749162), 'surprise': np.float32(24.533264), 'neutral': np.float32(0.22810054)}, 'dominant_emotion': 'angry', 'region': {'x': 506, 'y': 222, 'w': 354, 'h': 354, 'left_eye': (753, 353), 'right_eye': (602, 351)}, 'face_confidence': np.float64(0.89)}]
# Result: [{'emotion': {'angry': np.float32(6.089487), 'disgust': np.float32(2.931381e-06), 'fear': np.float32(5.7735705), 'happy': np.float32(0.00078701484), 'sad': np.float32(12.17697), 'surprise': np.float32(0.20651996), 'neutral': np.float32(75.75267)}, 'dominant_emotion': 'neutral', 'region': {'x': 508, 'y': 226, 'w': 345, 'h': 345, 'left_eye': (753, 353), 'right_eye': (603, 351)}, 'face_confidence': np.float64(0.87)}]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 12
#       9     break
#      11 try:
# ---> 12     result = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False)
#      13     print("Result:", result)
#      14     dominant_emotion = result[0]['dominant_emotion']
#
# File /opt/miniconda3/envs/myvoiceenv/lib/python3.10/site-packages/deepface/DeepFace.py:253, in analyze(img_path, actions, enforce_detection, detector_backend, align, expand_percentage, silent, anti_spoofing)
#     166 def analyze(
#     167     img_path: Union[str, np.ndarray],
#     168     actions: Union[tuple, list] = ("emotion", "age", "gender", "race"),
#    (...)
#     174     anti_spoofing: bool = False,
#     175 ) -> List[Dict[str, Any]]:
#     176     """
#     177     Analyze facial attributes such as age, gender, emotion, and race in the provided image.
#     178     Args:
#    (...)
#     251             - 'white': Confidence score for White ethnicity.
#     252     """
# --> 253     return demography.analyze(
#     254         img_path=img_path,
#     255         actions=actions,
#     256         enforce_detection=enforce_detection,
#     257         detector_backend=detector_backend,
#     258         align=align,
#     259         expand_percentage=expand_percentage,
#     260         silent=silent,
#     261         anti_spoofing=anti_spoofing,
#     262     )
#
# File /opt/miniconda3/envs/myvoiceenv/lib/python3.10/site-packages/deepface/modules/demography.py:123, in analyze(img_path, actions, enforce_detection, detector_backend, align, expand_percentage, silent, anti_spoofing)
#     120 # ---------------------------------
#     121 resp_objects = []
# --> 123 img_objs = detection.extract_faces(
#     124     img_path=img_path,
#     125     detector_backend=detector_backend,
#     126     enforce_detection=enforce_detection,
#     127     grayscale=False,
#     128     align=align,
#     129     expand_percentage=expand_percentage,
#     130     anti_spoofing=anti_spoofing,
#     131 )
#     133 for img_obj in img_objs:
#     134     if anti_spoofing is True and img_obj.get("is_real", True) is False:
#
# File /opt/miniconda3/envs/myvoiceenv/lib/python3.10/site-packages/deepface/modules/detection.py:95, in extract_faces(img_path, detector_backend, enforce_detection, align, expand_percentage, grayscale, color_face, normalize_face, anti_spoofing)
#      93     face_objs = [DetectedFace(img=img, facial_area=base_region, confidence=0)]
#      94 else:
# ---> 95     face_objs = detect_faces(
#      96         detector_backend=detector_backend,
#      97         img=img,
#      98         align=align,
#      99         expand_percentage=expand_percentage,
#     100     )
#     102 # in case of no face found
#     103 if len(face_objs) == 0 and enforce_detection is True:
#
# File /opt/miniconda3/envs/myvoiceenv/lib/python3.10/site-packages/deepface/modules/detection.py:262, in detect_faces(detector_backend, img, align, expand_percentage)
#     260 # align original image, then find projection of detected face area after alignment
#     261 if align is True:  # and left_eye is not None and right_eye is not None:
# --> 262     aligned_img, angle = align_img_wrt_eyes(img=img, left_eye=left_eye, right_eye=right_eye)
#     264     rotated_x1, rotated_y1, rotated_x2, rotated_y2 = project_facial_area(
#     265         facial_area=(x, y, x + w, y + h), angle=angle, size=(img.shape[0], img.shape[1])
#     266     )
#     267     detected_face = aligned_img[
#     268         int(rotated_y1) : int(rotated_y2), int(rotated_x1) : int(rotated_x2)
#     269     ]
#
# File /opt/miniconda3/envs/myvoiceenv/lib/python3.10/site-packages/deepface/modules/detection.py:314, in align_img_wrt_eyes(img, left_eye, right_eye)
#     311     return img, 0
#     313 angle = float(np.degrees(np.arctan2(left_eye[1] - right_eye[1], left_eye[0] - right_eye[0])))
# --> 314 img = np.array(Image.fromarray(img).rotate(angle, resample=Image.BICUBIC))
#     315 return img, angle
#
# File /opt/miniconda3/envs/myvoiceenv/lib/python3.10/site-packages/PIL/Image.py:2465, in Image.rotate(self, angle, resample, expand, center, translate, fillcolor)
#    2462     matrix[2], matrix[5] = transform(-(nw - w) / 2.0, -(nh - h) / 2.0, matrix)
#    2463     w, h = nw, nh
# -> 2465 return self.transform(
#    2466     (w, h), Transform.AFFINE, matrix, resample, fillcolor=fillcolor
#    2467 )
#
# File /opt/miniconda3/envs/myvoiceenv/lib/python3.10/site-packages/PIL/Image.py:2871, in Image.transform(self, size, method, data, resample, fill, fillcolor)
#    2867         im.__transformer(
#    2868             box, self, Transform.QUAD, quad, resample, fillcolor is None
#    2869         )
#    2870 else:
# -> 2871     im.__transformer(
#    2872         (0, 0) + size, self, method, data, resample, fillcolor is None
#    2873     )
#    2875 return im
#
# File /opt/miniconda3/envs/myvoiceenv/lib/python3.10/site-packages/PIL/Image.py:2961, in Image.__transformer(self, box, image, method, data, resample, fill)
#    2958 if image.mode in ("1", "P"):
#    2959     resample = Resampling.NEAREST
# -> 2961 self.im.transform(box, image.im, method, data, resample, fill)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2
from deepface import DeepFace

cap = cv2.VideoCapture(0)
frame_count = 0
emotion_label = ""

while True:
    ret, frame = cap.read()
    if not ret:
        break

    if frame_count % 60 == 0:
        try:
            result = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False)
            if result:
                emotion_label = result[0]['dominant_emotion']
        except Exception as e:
            print("Error:", e)

    frame_count += 1

    cv2.putText(frame, emotion_label, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 
                1, (255, 255, 255), 2, cv2.LINE_8)
    cv2.imshow("Emotion Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
